# %% [markdown]
# # MATSim Data Pipeline
# This script serves to try out functions that prepares data for the generation of MATSim Population, Config and Networks
#
# Steps include:
#
# * Extracting the official adminstrative boundaries of the regio

# %%
#Import relevant libraries
from data_helperfunctions import *
from utils import PROJECT_ROOT, OSM_DIR

# %%
url= "https://api3.geo.admin.ch/rest/services/api/MapServer/ch.swisstopo.swissboundaries3d-bezirk-flaeche.fill/2104?geometryFormat=geojson&sr=4326"
url_mun="https://api3.geo.admin.ch/rest/services/api/MapServer/ch.swisstopo.swissboundaries3d-gemeinde-flaeche.fill/5113?geometryFormat=geojson&sr=4326"
#Get_Shapefile(url, "Locarno_Boundary", target_crs="EPSG:2056")
Get_Shapefile(url_mun, "Locarno_Municipality_Boundary", target_crs="EPSG:2056")
# Out:
# Shapefile saved to: C:\Users\20201733\Documents\Thesis\Git_Master_Thesis\data\osm\shapes\Locarno_Municipality_Boundary.shp
# c:\Users\20201733\Documents\Thesis\Git_Master_Thesis\preprocessing\data_helperfunctions.py:53: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf.to_file(output_file)
# c:\Users\20201733\AppData\Local\anaconda3\envs\thesis\Lib\site-packages\pyogrio\raw.py:733: RuntimeWarning: Normalized/laundered field name: 'gde_hist_id' to 'gde_hist_i'
#   ogr_write(
# c:\Users\20201733\AppData\Local\anaconda3\envs\thesis\Lib\site-packages\pyogrio\raw.py:733: RuntimeWarning: Normalized/laundered field name: 'is_current_jahr' to 'is_current'
#   ogr_write(
# c:\Users\20201733\AppData\Local\anaconda3\envs\thesis\Lib\site-packages\pyogrio\raw.py:733: RuntimeWarning: Normalized/laundered field name: 'objektart_lookup' to 'objektart_'
#   ogr_write(
# ...
